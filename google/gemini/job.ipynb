# %%
# Instalar as bibliotecas necessárias
# %pip install langchain-google-genai
# %pip install langchain
# %pip install pypdf
# %pip install faiss-cpu
# %pip install sentence-transformers
# Out:
# Collecting langchain-google-genai
#   Downloading langchain_google_genai-2.1.9-py3-none-any.whl.metadata (7.2 kB)
# Collecting filetype<2.0.0,>=1.2.0 (from langchain-google-genai)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting google-ai-generativelanguage<0.7.0,>=0.6.18 (from langchain-google-genai)
#   Downloading google_ai_generativelanguage-0.6.18-py3-none-any.whl.metadata (9.8 kB)
# Collecting langchain-core<0.4.0,>=0.3.68 (from langchain-google-genai)
#   Downloading langchain_core-0.3.74-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: pydantic<3,>=2 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from langchain-google-genai) (2.11.4)
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai)
#   Downloading google_api_core-2.25.1-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (2.40.3)
# Collecting proto-plus<2.0.0,>=1.22.3 (from google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai)
#   Downloading proto_plus-1.26.1-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (6.31.1)
# Collecting langsmith>=0.3.45 (from langchain-core<0.4.0,>=0.3.68->langchain-google-genai)
#   Downloading langsmith-0.4.16-py3-none-any.whl.metadata (14 kB)
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0 (from langchain-core<0.4.0,>=0.3.68->langchain-google-genai)
#   Using cached tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<0.4.0,>=0.3.68->langchain-google-genai)
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: PyYAML>=5.3 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.68->langchain-google-genai) (6.0.2)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.68->langchain-google-genai) (4.13.2)
# Requirement already satisfied: packaging>=23.2 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.68->langchain-google-genai) (25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from pydantic<3,>=2->langchain-google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from pydantic<3,>=2->langchain-google-genai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from pydantic<3,>=2->langchain-google-genai) (0.4.0)
# Collecting googleapis-common-protos<2.0.0,>=1.56.2 (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai)
#   Using cached googleapis_common_protos-1.70.0-py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (2.32.4)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (1.73.0)
# Collecting grpcio-status<2.0.0,>=1.33.2 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai)
#   Downloading grpcio_status-1.74.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (4.9.1)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.68->langchain-google-genai)
#   Using cached jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.68->langchain-google-genai) (0.28.1)
# Collecting orjson>=3.9.14 (from langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.68->langchain-google-genai)
#   Downloading orjson-3.11.2-cp311-cp311-macosx_15_0_arm64.whl.metadata (1.2 kB)
# Collecting requests-toolbelt>=1.0.0 (from langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.68->langchain-google-genai)
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting zstandard>=0.23.0 (from langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.68->langchain-google-genai)
#   Downloading zstandard-0.24.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (3.1 kB)
# Collecting grpcio<2.0.0,>=1.33.2 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai)
#   Downloading grpcio-1.74.0-cp311-cp311-macosx_11_0_universal2.whl.metadata (3.8 kB)
# Requirement already satisfied: anyio in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.68->langchain-google-genai) (4.9.0)
# Requirement already satisfied: certifi in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.68->langchain-google-genai) (2025.6.15)
# Requirement already satisfied: httpcore==1.* in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.68->langchain-google-genai) (1.0.9)
# Requirement already satisfied: idna in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.68->langchain-google-genai) (3.10)
# Requirement already satisfied: h11>=0.16 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.68->langchain-google-genai) (0.16.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (0.6.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<0.7.0,>=0.6.18->langchain-google-genai) (2.4.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.3.45->langchain-core<0.4.0,>=0.3.68->langchain-google-genai) (1.3.1)
# Downloading langchain_google_genai-2.1.9-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 1.1 MB/s eta 0:00:00a 0:00:01
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading google_ai_generativelanguage-0.6.18-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 20.3 MB/s eta 0:00:00a 0:00:01
# Downloading langchain_core-0.3.74-py3-none-any.whl (443 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 443.5/443.5 kB 58.6 MB/s eta 0:00:00
# Downloading google_api_core-2.25.1-py3-none-any.whl (160 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.8/160.8 kB 25.4 MB/s eta 0:00:00
# Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading langsmith-0.4.16-py3-none-any.whl (375 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 375.8/375.8 kB 52.5 MB/s eta 0:00:00
# Downloading proto_plus-1.26.1-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 8.0 MB/s eta 0:00:00
# Using cached tenacity-9.1.2-py3-none-any.whl (28 kB)
# Using cached googleapis_common_protos-1.70.0-py3-none-any.whl (294 kB)
# Downloading grpcio_status-1.74.0-py3-none-any.whl (14 kB)
# Downloading grpcio-1.74.0-cp311-cp311-macosx_11_0_universal2.whl (11.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 78.6 MB/s eta 0:00:00 0:00:01m
# Using cached jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Downloading orjson-3.11.2-cp311-cp311-macosx_15_0_arm64.whl (115 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.0/116.0 kB 16.1 MB/s eta 0:00:00
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Downloading zstandard-0.24.0-cp311-cp311-macosx_11_0_arm64.whl (640 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 640.5/640.5 kB 58.6 MB/s eta 0:00:00
# Installing collected packages: filetype, zstandard, tenacity, proto-plus, orjson, jsonpointer, grpcio, googleapis-common-protos, requests-toolbelt, jsonpatch, grpcio-status, langsmith, google-api-core, langchain-core, google-ai-generativelanguage, langchain-google-genai
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.73.0
#     Uninstalling grpcio-1.73.0:
#       Successfully uninstalled grpcio-1.73.0
# Successfully installed filetype-1.2.0 google-ai-generativelanguage-0.6.18 google-api-core-2.25.1 googleapis-common-protos-1.70.0 grpcio-1.74.0 grpcio-status-1.74.0 jsonpatch-1.33 jsonpointer-3.0.0 langchain-core-0.3.74 langchain-google-genai-2.1.9 langsmith-0.4.16 orjson-3.11.2 proto-plus-1.26.1 requests-toolbelt-1.0.0 tenacity-9.1.2 zstandard-0.24.0
#
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Collecting langchain
#   Downloading langchain-0.3.27-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.72 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from langchain) (0.3.74)
# Collecting langchain-text-splitters<1.0.0,>=0.3.9 (from langchain)
#   Downloading langchain_text_splitters-0.3.9-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: langsmith>=0.1.17 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from langchain) (0.4.16)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from langchain) (2.11.4)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from langchain) (2.0.41)
# Requirement already satisfied: requests<3,>=2 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from langchain) (2.32.4)
# Requirement already satisfied: PyYAML>=5.3 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from langchain) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (1.33)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (4.13.2)
# Requirement already satisfied: packaging>=23.2 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (25.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from langsmith>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from langsmith>=0.1.17->langchain) (3.11.2)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from langsmith>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from langsmith>=0.1.17->langchain) (0.24.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from requests<3,>=2->langchain) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from requests<3,>=2->langchain) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from requests<3,>=2->langchain) (2025.6.15)
# Requirement already satisfied: anyio in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.72->langchain) (3.0.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (1.3.1)
# Downloading langchain-0.3.27-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 12.0 MB/s eta 0:00:00a 0:00:01
# Downloading langchain_text_splitters-0.3.9-py3-none-any.whl (33 kB)
# Installing collected packages: langchain-text-splitters, langchain
# Successfully installed langchain-0.3.27 langchain-text-splitters-0.3.9
#
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Collecting pypdf
#   Downloading pypdf-6.0.0-py3-none-any.whl.metadata (7.1 kB)
# Downloading pypdf-6.0.0-py3-none-any.whl (310 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.5/310.5 kB 4.0 MB/s eta 0:00:0000:0100:01
# Installing collected packages: pypdf
# Successfully installed pypdf-6.0.0
#
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: faiss-cpu in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (1.11.0)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from faiss-cpu) (2.3.0)
# Requirement already satisfied: packaging in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from faiss-cpu) (25.0)
#
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: sentence-transformers in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (4.1.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from sentence-transformers) (4.52.4)
# Requirement already satisfied: tqdm in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from sentence-transformers) (2.7.1)
# Requirement already satisfied: scikit-learn in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from sentence-transformers) (1.7.0)
# Requirement already satisfied: scipy in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from sentence-transformers) (1.15.3)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from sentence-transformers) (0.33.0)
# Requirement already satisfied: Pillow in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from sentence-transformers) (11.2.1)
# Requirement already satisfied: typing_extensions>=4.5.0 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from sentence-transformers) (4.13.2)
# Requirement already satisfied: filelock in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.5.1)
# Requirement already satisfied: packaging>=20.9 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: requests in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.4)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.1.4)
# Requirement already satisfied: sympy>=1.13.3 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (3.5)
# Requirement already satisfied: jinja2 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: numpy>=1.17 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.3)
# Requirement already satisfied: joblib>=1.2.0 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from scikit-learn->sentence-transformers) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2025.6.15)
#
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install langchain_community
# Out:
# Collecting langchain_community
#   Downloading langchain_community-0.3.27-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.66 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from langchain_community) (0.3.74)
# Requirement already satisfied: langchain<1.0.0,>=0.3.26 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from langchain_community) (0.3.27)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from langchain_community) (2.0.41)
# Requirement already satisfied: requests<3,>=2 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from langchain_community) (2.32.4)
# Requirement already satisfied: PyYAML>=5.3 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from langchain_community) (6.0.2)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain_community)
#   Downloading aiohttp-3.12.15-cp311-cp311-macosx_11_0_arm64.whl.metadata (7.7 kB)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from langchain_community) (9.1.2)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain_community)
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.4.0 (from langchain_community)
#   Downloading pydantic_settings-2.10.1-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: langsmith>=0.1.125 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from langchain_community) (0.4.16)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain_community)
#   Downloading httpx_sse-0.4.1-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: numpy>=1.26.2 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from langchain_community) (2.3.0)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Downloading aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting attrs>=17.3.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Using cached attrs-25.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Using cached frozenlist-1.7.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (18 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Downloading multidict-6.6.4-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Using cached propcache-0.3.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (12 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Using cached yarl-1.20.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (73 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain_community)
#   Using cached marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain_community)
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from langchain<1.0.0,>=0.3.26->langchain_community) (0.3.9)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from langchain<1.0.0,>=0.3.26->langchain_community) (2.11.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.66->langchain_community) (1.33)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.66->langchain_community) (4.13.2)
# Requirement already satisfied: packaging>=23.2 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.66->langchain_community) (25.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from langsmith>=0.1.125->langchain_community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from langsmith>=0.1.125->langchain_community) (3.11.2)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from langsmith>=0.1.125->langchain_community) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from langsmith>=0.1.125->langchain_community) (0.24.0)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.4.0->langchain_community)
#   Downloading python_dotenv-1.1.1-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain_community) (0.4.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from requests<3,>=2->langchain_community) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from requests<3,>=2->langchain_community) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from requests<3,>=2->langchain_community) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from requests<3,>=2->langchain_community) (2025.6.15)
# Requirement already satisfied: anyio in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.125->langchain_community) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.125->langchain_community) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.1.125->langchain_community) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.66->langchain_community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.26->langchain_community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.26->langchain_community) (2.33.2)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community)
#   Using cached mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: sniffio>=1.1 in /Users/clarissacolaco/.pyenv/versions/ipynb/lib/python3.11/site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.1.125->langchain_community) (1.3.1)
# Downloading langchain_community-0.3.27-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 23.7 MB/s eta 0:00:00a 0:00:01
# Downloading aiohttp-3.12.15-cp311-cp311-macosx_11_0_arm64.whl (471 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 471.8/471.8 kB 61.0 MB/s eta 0:00:00
# Using cached dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading httpx_sse-0.4.1-py3-none-any.whl (8.1 kB)
# Downloading pydantic_settings-2.10.1-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 kB 5.7 MB/s eta 0:00:00
# Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Using cached attrs-25.3.0-py3-none-any.whl (63 kB)
# Using cached frozenlist-1.7.0-cp311-cp311-macosx_11_0_arm64.whl (47 kB)
# Using cached marshmallow-3.26.1-py3-none-any.whl (50 kB)
# Downloading multidict-6.6.4-cp311-cp311-macosx_11_0_arm64.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 5.3 MB/s eta 0:00:00
# Using cached propcache-0.3.2-cp311-cp311-macosx_11_0_arm64.whl (43 kB)
# Downloading python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Using cached yarl-1.20.1-cp311-cp311-macosx_11_0_arm64.whl (89 kB)
# Using cached mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Installing collected packages: python-dotenv, propcache, mypy-extensions, multidict, marshmallow, httpx-sse, frozenlist, attrs, aiohappyeyeballs, yarl, typing-inspect, aiosignal, pydantic-settings, dataclasses-json, aiohttp, langchain_community
# Successfully installed aiohappyeyeballs-2.6.1 aiohttp-3.12.15 aiosignal-1.4.0 attrs-25.3.0 dataclasses-json-0.6.7 frozenlist-1.7.0 httpx-sse-0.4.1 langchain_community-0.3.27 marshmallow-3.26.1 multidict-6.6.4 mypy-extensions-1.1.0 propcache-0.3.2 pydantic-settings-2.10.1 python-dotenv-1.1.1 typing-inspect-0.9.0 yarl-1.20.1
#
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from env import MY_KEY

# %%
from langchain_community.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter

# Carregar o documento
loader = PyPDFLoader("meu-pdf.pdf")
docs = loader.load()

# Dividir o texto em pedaços menores (chunks)
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
chunks = text_splitter.split_documents(docs)

# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings
from langchain_community.vectorstores import FAISS

# Configurar a chave de API do Gemini
import os
import os
from dotenv import load_dotenv

# Carrega as variáveis de ambiente do arquivo .env
load_dotenv()

# Agora a chave está disponível

if MY_KEY:
    os.environ['GOOGLE_API_KEY'] = MY_KEY
    print("Chave de API carregada com sucesso.")
else:
    print("A chave de API não foi encontrada no arquivo .env.")
# Out:
# Chave de API carregada com sucesso.

# %%
# Criar embeddings (vetores) para os chunks
embeddings = GoogleGenerativeAIEmbeddings(model="models/embedding-001")
vector_store = FAISS.from_documents(chunks, embeddings)

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.chains import RetrievalQA

# Inicializar o modelo Gemini
llm = ChatGoogleGenerativeAI(model="gemini-1.5-flash")

# Criar a cadeia de RAG
qa_chain = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",
    retriever=vector_store.as_retriever()
)

# %%
# Faça uma pergunta com base no conteúdo do seu PDF
# pergunta = "Qual é o principal tópico abordado no documento?"
pergunta = "O que é um hobbit? Como aparece no texto?"
resposta = qa_chain.run(pergunta)

print(resposta)
# Out:
# De acordo com o texto, hobbits são os habitantes pacíficos do Condado, onde a história começa de forma despretensiosa.  Bilbo Bolseiro e Frodo são hobbits.  O texto descreve hobbits como parte da Sociedade do Anel, junto com outros personagens de diferentes raças.
